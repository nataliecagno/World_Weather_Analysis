# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 764

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | carmen
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | lagoa
# Processing Record 5 of Set 1 | mecca
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | wuan
# Processing Record 8 of Set 1 | palmer
# Processing Record 9 of Set 1 | nanortalik
# Processing Record 10 of Set 1 | soroti
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | grand gaube
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | biltine
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | oyon
# Processing Record 17 of Set 1 | zaragoza
# Processing Record 18 of Set 1 | ulaanbaatar
# Processing Record 19 of Set 1 | severo-kurilsk
# Processing Record 20 of Set 1 | marawi
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | brownwood
# Processing Record 23 of Set 1 | nishihara
# Processing Record 24 of Set 1 | hasaki
# Processing Record 25 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | esperance
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | provideniya
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 1 | mendi
# Processing Record 33 of Set 1 | havre-saint-pierre
# Processing Record 34 of Set 1 | dakar
# Processing Record 35 of Set 1 | hamilton
# Processing Record 36 of Set 1 | bethel
# Processing Record 37 of Set 1 | praia da vitoria
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | ostrovnoy
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 1 | aldan
# Processing Record 49 of Set 1 | port augusta
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | sande
# Processing Record 2 of Set 2 | resistencia
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | noumea
# Processing Record 5 of Set 2 | luderitz
# Processing Record 6 of Set 2 | victoria
# Processing Record 7 of Set 2 | cumbitara
# Processing Record 8 of Set 2 | burns lake
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | athabasca
# Processing Record 11 of Set 2 | paredon
# Processing Record 12 of Set 2 | pisco
# Processing Record 13 of Set 2 | marystown
# Processing Record 14 of Set 2 | new norfolk
# Processing Record 15 of Set 2 | rairangpur
# Processing Record 16 of Set 2 | mapimi
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | kamaishi
# Processing Record 21 of Set 2 | victor harbor
# Processing Record 22 of Set 2 | sao filipe
# Processing Record 23 of Set 2 | tanete
# Processing Record 24 of Set 2 | san lawrenz
# Processing Record 25 of Set 2 | yavoriv
# Processing Record 26 of Set 2 | boyolangu
# Processing Record 27 of Set 2 | naze
# Processing Record 28 of Set 2 | puerto el triunfo
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | mount isa
# Processing Record 31 of Set 2 | tucuman
# Processing Record 32 of Set 2 | ust-kulom
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | punta arenas
# Processing Record 35 of Set 2 | mmabatho
# Processing Record 36 of Set 2 | coquimbo
# Processing Record 37 of Set 2 | beringovskiy
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | cherskiy
# Processing Record 40 of Set 2 | maramba
# Processing Record 41 of Set 2 | broome
# Processing Record 42 of Set 2 | saint-georges
# Processing Record 43 of Set 2 | auki
# Processing Record 44 of Set 2 | gzhatsk
# City not found. Skipping...
# Processing Record 45 of Set 2 | ancud
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 48 of Set 2 | atambua
# Processing Record 49 of Set 2 | smithers
# Processing Record 50 of Set 2 | jamestown
# Processing Record 1 of Set 3 | codrington
# Processing Record 2 of Set 3 | troitsko-pechorsk
# Processing Record 3 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 3 | suhut
# Processing Record 5 of Set 3 | najran
# Processing Record 6 of Set 3 | buta
# Processing Record 7 of Set 3 | pangoa
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | whitehorse
# Processing Record 10 of Set 3 | atuona
# Processing Record 11 of Set 3 | la libertad
# Processing Record 12 of Set 3 | toamasina
# Processing Record 13 of Set 3 | rapid valley
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | hambantota
# Processing Record 16 of Set 3 | alimanguan
# City not found. Skipping...
# Processing Record 17 of Set 3 | sehithwa
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | awbari
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | tselinnoye
# Processing Record 22 of Set 3 | port alfred
# Processing Record 23 of Set 3 | hovd
# Processing Record 24 of Set 3 | ciudad guayana
# Processing Record 25 of Set 3 | garowe
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | lazaro cardenas
# Processing Record 29 of Set 3 | flinders
# Processing Record 30 of Set 3 | saint george
# Processing Record 31 of Set 3 | baykit
# Processing Record 32 of Set 3 | havelock
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | naliya
# Processing Record 35 of Set 3 | asau
# Processing Record 36 of Set 3 | henties bay
# Processing Record 37 of Set 3 | de-kastri
# Processing Record 38 of Set 3 | saint-francois
# Processing Record 39 of Set 3 | fort nelson
# Processing Record 40 of Set 3 | muyezerskiy
# Processing Record 41 of Set 3 | kushima
# Processing Record 42 of Set 3 | margate
# Processing Record 43 of Set 3 | tuatapere
# Processing Record 44 of Set 3 | orange
# Processing Record 45 of Set 3 | strathmore
# Processing Record 46 of Set 3 | puerto ayora
# Processing Record 47 of Set 3 | yeppoon
# Processing Record 48 of Set 3 | nushki
# Processing Record 49 of Set 3 | namatanai
# Processing Record 50 of Set 3 | belaya gora
# Processing Record 1 of Set 4 | avarua
# Processing Record 2 of Set 4 | pevek
# Processing Record 3 of Set 4 | yulara
# Processing Record 4 of Set 4 | kodiak
# Processing Record 5 of Set 4 | kunda
# Processing Record 6 of Set 4 | felidhoo
# City not found. Skipping...
# Processing Record 7 of Set 4 | norman wells
# Processing Record 8 of Set 4 | aksarka
# Processing Record 9 of Set 4 | acari
# Processing Record 10 of Set 4 | awjilah
# Processing Record 11 of Set 4 | bourg-en-bresse
# Processing Record 12 of Set 4 | pochutla
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | east london
# Processing Record 15 of Set 4 | trairi
# Processing Record 16 of Set 4 | boromlya
# Processing Record 17 of Set 4 | dingle
# Processing Record 18 of Set 4 | teguldet
# Processing Record 19 of Set 4 | kieta
# Processing Record 20 of Set 4 | along
# Processing Record 21 of Set 4 | casablanca
# Processing Record 22 of Set 4 | quelimane
# Processing Record 23 of Set 4 | manuk mangkaw
# Processing Record 24 of Set 4 | sladkovo
# Processing Record 25 of Set 4 | sinop
# Processing Record 26 of Set 4 | pauini
# Processing Record 27 of Set 4 | diapaga
# Processing Record 28 of Set 4 | vao
# Processing Record 29 of Set 4 | we
# City not found. Skipping...
# Processing Record 30 of Set 4 | quatre cocos
# Processing Record 31 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 4 | banjar
# Processing Record 33 of Set 4 | faanui
# Processing Record 34 of Set 4 | buraydah
# Processing Record 35 of Set 4 | warrnambool
# Processing Record 36 of Set 4 | mount gambier
# Processing Record 37 of Set 4 | necochea
# Processing Record 38 of Set 4 | ternate
# Processing Record 39 of Set 4 | ushtobe
# Processing Record 40 of Set 4 | longyearbyen
# Processing Record 41 of Set 4 | mancio lima
# Processing Record 42 of Set 4 | teguise
# Processing Record 43 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 44 of Set 4 | moose factory
# Processing Record 45 of Set 4 | ayan
# Processing Record 46 of Set 4 | limbang
# Processing Record 47 of Set 4 | castro
# Processing Record 48 of Set 4 | dumka
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 50 of Set 4 | natal
# Processing Record 1 of Set 5 | goderich
# Processing Record 2 of Set 5 | san rafael
# Processing Record 3 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 5 | waspan
# Processing Record 5 of Set 5 | charlestown
# Processing Record 6 of Set 5 | tabarqah
# City not found. Skipping...
# Processing Record 7 of Set 5 | portland
# Processing Record 8 of Set 5 | sao joao da barra
# Processing Record 9 of Set 5 | kirakira
# Processing Record 10 of Set 5 | olafsvik
# Processing Record 11 of Set 5 | luchegorsk
# Processing Record 12 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 5 | solvychegodsk
# Processing Record 14 of Set 5 | lufilufi
# Processing Record 15 of Set 5 | kavieng
# Processing Record 16 of Set 5 | shimoda
# Processing Record 17 of Set 5 | lavrentiya
# Processing Record 18 of Set 5 | nouadhibou
# Processing Record 19 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 5 | wattegama
# Processing Record 22 of Set 5 | chicama
# Processing Record 23 of Set 5 | bambous virieux
# Processing Record 24 of Set 5 | palekh
# Processing Record 25 of Set 5 | vero beach
# Processing Record 26 of Set 5 | aksu
# Processing Record 27 of Set 5 | saskylakh
# Processing Record 28 of Set 5 | caravelas
# Processing Record 29 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 5 | ahipara
# Processing Record 31 of Set 5 | kinel
# Processing Record 32 of Set 5 | maningrida
# Processing Record 33 of Set 5 | ust-omchug
# Processing Record 34 of Set 5 | kachiry
# Processing Record 35 of Set 5 | manicore
# Processing Record 36 of Set 5 | tabou
# Processing Record 37 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 5 | dombarovskiy
# Processing Record 39 of Set 5 | kayes
# Processing Record 40 of Set 5 | beisfjord
# Processing Record 41 of Set 5 | irpa irpa
# Processing Record 42 of Set 5 | salalah
# Processing Record 43 of Set 5 | ballina
# Processing Record 44 of Set 5 | leningradskiy
# Processing Record 45 of Set 5 | nkayi
# Processing Record 46 of Set 5 | saposoa
# Processing Record 47 of Set 5 | jacareacanga
# Processing Record 48 of Set 5 | francisco sa
# Processing Record 49 of Set 5 | flin flon
# Processing Record 50 of Set 5 | vila velha
# Processing Record 1 of Set 6 | bilma
# Processing Record 2 of Set 6 | faya
# Processing Record 3 of Set 6 | gazli
# Processing Record 4 of Set 6 | craig
# Processing Record 5 of Set 6 | port said
# Processing Record 6 of Set 6 | srednekolymsk
# Processing Record 7 of Set 6 | ngunguru
# Processing Record 8 of Set 6 | mawlaik
# Processing Record 9 of Set 6 | hofn
# Processing Record 10 of Set 6 | deputatskiy
# Processing Record 11 of Set 6 | thompson
# Processing Record 12 of Set 6 | morro bay
# Processing Record 13 of Set 6 | seymchan
# Processing Record 14 of Set 6 | jieshi
# Processing Record 15 of Set 6 | morehead
# Processing Record 16 of Set 6 | ilulissat
# Processing Record 17 of Set 6 | dunedin
# Processing Record 18 of Set 6 | luis correia
# Processing Record 19 of Set 6 | bandipur
# Processing Record 20 of Set 6 | samarai
# Processing Record 21 of Set 6 | richards bay
# Processing Record 22 of Set 6 | ravar
# Processing Record 23 of Set 6 | hettstedt
# Processing Record 24 of Set 6 | sibolga
# Processing Record 25 of Set 6 | aswan
# Processing Record 26 of Set 6 | fairmount
# Processing Record 27 of Set 6 | suntar
# Processing Record 28 of Set 6 | kincardine
# Processing Record 29 of Set 6 | mahebourg
# Processing Record 30 of Set 6 | mpika
# Processing Record 31 of Set 6 | saint-joseph
# Processing Record 32 of Set 6 | hastings
# Processing Record 33 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 34 of Set 6 | touros
# Processing Record 35 of Set 6 | meulaboh
# Processing Record 36 of Set 6 | coihaique
# Processing Record 37 of Set 6 | koslan
# Processing Record 38 of Set 6 | balkhash
# Processing Record 39 of Set 6 | voyvozh
# Processing Record 40 of Set 6 | port lincoln
# Processing Record 41 of Set 6 | qaqortoq
# Processing Record 42 of Set 6 | upernavik
# Processing Record 43 of Set 6 | aguilas
# Processing Record 44 of Set 6 | nyurba
# Processing Record 45 of Set 6 | pringsewu
# Processing Record 46 of Set 6 | katsuura
# Processing Record 47 of Set 6 | sambava
# Processing Record 48 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 6 | tra vinh
# Processing Record 50 of Set 6 | jumla
# Processing Record 1 of Set 7 | inhambane
# Processing Record 2 of Set 7 | alpena
# Processing Record 3 of Set 7 | upata
# Processing Record 4 of Set 7 | vikindu
# Processing Record 5 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 6 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 7 | khromtau
# Processing Record 9 of Set 7 | souillac
# Processing Record 10 of Set 7 | port hardy
# Processing Record 11 of Set 7 | juneau
# Processing Record 12 of Set 7 | lake havasu city
# Processing Record 13 of Set 7 | broken hill
# Processing Record 14 of Set 7 | torbay
# Processing Record 15 of Set 7 | great yarmouth
# Processing Record 16 of Set 7 | lompoc
# Processing Record 17 of Set 7 | ixtapa
# Processing Record 18 of Set 7 | mazagao
# Processing Record 19 of Set 7 | haines junction
# Processing Record 20 of Set 7 | fortuna
# Processing Record 21 of Set 7 | narsaq
# Processing Record 22 of Set 7 | pangody
# Processing Record 23 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 7 | darhan
# Processing Record 25 of Set 7 | negara
# Processing Record 26 of Set 7 | strezhevoy
# Processing Record 27 of Set 7 | namibe
# Processing Record 28 of Set 7 | winslow
# Processing Record 29 of Set 7 | buala
# Processing Record 30 of Set 7 | lucapa
# Processing Record 31 of Set 7 | tavda
# Processing Record 32 of Set 7 | araguacu
# Processing Record 33 of Set 7 | wajir
# Processing Record 34 of Set 7 | manadhoo
# Processing Record 35 of Set 7 | ventspils
# Processing Record 36 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 7 | cidreira
# Processing Record 38 of Set 7 | rosetta
# Processing Record 39 of Set 7 | erenhot
# Processing Record 40 of Set 7 | ayagoz
# Processing Record 41 of Set 7 | kruisfontein
# Processing Record 42 of Set 7 | kaseda
# Processing Record 43 of Set 7 | zhigansk
# Processing Record 44 of Set 7 | pangkalanbuun
# Processing Record 45 of Set 7 | vanimo
# Processing Record 46 of Set 7 | cabo san lucas
# Processing Record 47 of Set 7 | port-gentil
# Processing Record 48 of Set 7 | aklavik
# Processing Record 49 of Set 7 | klaksvik
# Processing Record 50 of Set 7 | nantucket
# Processing Record 1 of Set 8 | ilinskiy
# Processing Record 2 of Set 8 | kant
# Processing Record 3 of Set 8 | serov
# Processing Record 4 of Set 8 | port macquarie
# Processing Record 5 of Set 8 | anadyr
# Processing Record 6 of Set 8 | karaton
# Processing Record 7 of Set 8 | itaituba
# Processing Record 8 of Set 8 | moron
# Processing Record 9 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 10 of Set 8 | alofi
# Processing Record 11 of Set 8 | sal rei
# Processing Record 12 of Set 8 | iqaluit
# Processing Record 13 of Set 8 | dongsheng
# Processing Record 14 of Set 8 | nioki
# Processing Record 15 of Set 8 | bubaque
# Processing Record 16 of Set 8 | maine-soroa
# Processing Record 17 of Set 8 | omboue
# Processing Record 18 of Set 8 | afsin
# Processing Record 19 of Set 8 | bengkulu
# Processing Record 20 of Set 8 | camapua
# Processing Record 21 of Set 8 | udachnyy
# Processing Record 22 of Set 8 | aden
# Processing Record 23 of Set 8 | kavaratti
# Processing Record 24 of Set 8 | sulangan
# Processing Record 25 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 26 of Set 8 | te anau
# Processing Record 27 of Set 8 | cliza
# Processing Record 28 of Set 8 | saint-pierre
# Processing Record 29 of Set 8 | adrar
# Processing Record 30 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 8 | marilia
# Processing Record 32 of Set 8 | bolu
# Processing Record 33 of Set 8 | ormara
# Processing Record 34 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 8 | misratah
# Processing Record 36 of Set 8 | oktyabrskoye
# Processing Record 37 of Set 8 | pacific grove
# Processing Record 38 of Set 8 | vardo
# Processing Record 39 of Set 8 | acajutla
# Processing Record 40 of Set 8 | zhanaozen
# Processing Record 41 of Set 8 | otane
# Processing Record 42 of Set 8 | seybaplaya
# Processing Record 43 of Set 8 | saldanha
# Processing Record 44 of Set 8 | jardim
# Processing Record 45 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 8 | savonlinna
# Processing Record 47 of Set 8 | tura
# Processing Record 48 of Set 8 | rawson
# Processing Record 49 of Set 8 | makakilo city
# Processing Record 50 of Set 8 | porto belo
# Processing Record 1 of Set 9 | huazolotitlan
# City not found. Skipping...
# Processing Record 2 of Set 9 | cabedelo
# Processing Record 3 of Set 9 | husavik
# Processing Record 4 of Set 9 | bitkine
# Processing Record 5 of Set 9 | volketswil
# Processing Record 6 of Set 9 | nome
# Processing Record 7 of Set 9 | kimbe
# Processing Record 8 of Set 9 | ruwi
# Processing Record 9 of Set 9 | makung
# City not found. Skipping...
# Processing Record 10 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 9 | emba
# Processing Record 12 of Set 9 | yumen
# Processing Record 13 of Set 9 | sorong
# Processing Record 14 of Set 9 | nabire
# Processing Record 15 of Set 9 | alto araguaia
# Processing Record 16 of Set 9 | berdigestyakh
# Processing Record 17 of Set 9 | atasu
# Processing Record 18 of Set 9 | sungaipenuh
# Processing Record 19 of Set 9 | djibo
# Processing Record 20 of Set 9 | pemangkat
# Processing Record 21 of Set 9 | sitka
# Processing Record 22 of Set 9 | inta
# Processing Record 23 of Set 9 | zaozerne
# Processing Record 24 of Set 9 | mantua
# Processing Record 25 of Set 9 | bandarbeyla
# Processing Record 26 of Set 9 | muravlenko
# Processing Record 27 of Set 9 | abbeyfeale
# Processing Record 28 of Set 9 | san cristobal
# Processing Record 29 of Set 9 | myitkyina
# Processing Record 30 of Set 9 | laguna
# Processing Record 31 of Set 9 | ketchikan
# Processing Record 32 of Set 9 | dossor
# Processing Record 33 of Set 9 | tsumeb
# Processing Record 34 of Set 9 | los llanos de aridane
# Processing Record 35 of Set 9 | kizema
# Processing Record 36 of Set 9 | miri
# Processing Record 37 of Set 9 | vestmannaeyjar
# Processing Record 38 of Set 9 | san jose
# Processing Record 39 of Set 9 | axim
# Processing Record 40 of Set 9 | kloulklubed
# Processing Record 41 of Set 9 | belmonte
# Processing Record 42 of Set 9 | high rock
# Processing Record 43 of Set 9 | kangaatsiaq
# Processing Record 44 of Set 9 | evanston
# Processing Record 45 of Set 9 | kumluca
# Processing Record 46 of Set 9 | qarqin
# Processing Record 47 of Set 9 | fairbanks
# Processing Record 48 of Set 9 | nalut
# Processing Record 49 of Set 9 | sai buri
# Processing Record 50 of Set 9 | mon
# Processing Record 1 of Set 10 | papara
# Processing Record 2 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 10 | naantali
# Processing Record 4 of Set 10 | bara
# Processing Record 5 of Set 10 | zhangye
# Processing Record 6 of Set 10 | matara
# Processing Record 7 of Set 10 | barra patuca
# Processing Record 8 of Set 10 | sao gabriel da cachoeira
# Processing Record 9 of Set 10 | clarksburg
# Processing Record 10 of Set 10 | sakakah
# Processing Record 11 of Set 10 | dhidhdhoo
# Processing Record 12 of Set 10 | pierre
# Processing Record 13 of Set 10 | pinawa
# Processing Record 14 of Set 10 | arraial do cabo
# Processing Record 15 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 16 of Set 10 | boden
# Processing Record 17 of Set 10 | bogovarovo
# Processing Record 18 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 19 of Set 10 | nouakchott
# Processing Record 20 of Set 10 | usta muhammad
# Processing Record 21 of Set 10 | katangli
# Processing Record 22 of Set 10 | tiksi
# Processing Record 23 of Set 10 | la ligua
# Processing Record 24 of Set 10 | bolitoc
# Processing Record 25 of Set 10 | warwick
# Processing Record 26 of Set 10 | kalmunai
# Processing Record 27 of Set 10 | indergarh
# Processing Record 28 of Set 10 | lola
# Processing Record 29 of Set 10 | sao jose da coroa grande
# Processing Record 30 of Set 10 | kidal
# Processing Record 31 of Set 10 | mamou
# Processing Record 32 of Set 10 | arman
# Processing Record 33 of Set 10 | sioux lookout
# Processing Record 34 of Set 10 | alta floresta
# Processing Record 35 of Set 10 | innisfail
# Processing Record 36 of Set 10 | georgetown
# Processing Record 37 of Set 10 | el reno
# Processing Record 38 of Set 10 | shingu
# Processing Record 39 of Set 10 | taunggyi
# Processing Record 40 of Set 10 | isangel
# Processing Record 41 of Set 10 | nata
# Processing Record 42 of Set 10 | palauig
# Processing Record 43 of Set 10 | kaitangata
# Processing Record 44 of Set 10 | alice springs
# Processing Record 45 of Set 10 | duldurga
# Processing Record 46 of Set 10 | marsa matruh
# Processing Record 47 of Set 10 | wodonga
# Processing Record 48 of Set 10 | medina del campo
# Processing Record 49 of Set 10 | san patricio
# Processing Record 50 of Set 10 | ontario
# Processing Record 1 of Set 11 | cockburn town
# Processing Record 2 of Set 11 | bratsk
# Processing Record 3 of Set 11 | bourail
# Processing Record 4 of Set 11 | puerto escondido
# Processing Record 5 of Set 11 | paamiut
# Processing Record 6 of Set 11 | hohhot
# Processing Record 7 of Set 11 | kasane
# Processing Record 8 of Set 11 | bonham
# Processing Record 9 of Set 11 | bela vista de goias
# Processing Record 10 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 11 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 12 of Set 11 | nanakuli
# Processing Record 13 of Set 11 | ratnagiri
# Processing Record 14 of Set 11 | severnyy
# Processing Record 15 of Set 11 | cascais
# Processing Record 16 of Set 11 | sonoita
# Processing Record 17 of Set 11 | ambulu
# Processing Record 18 of Set 11 | bereda
# Processing Record 19 of Set 11 | mersing
# Processing Record 20 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 21 of Set 11 | ponta delgada
# Processing Record 22 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 11 | assiniboia
# Processing Record 24 of Set 11 | tigzirt
# Processing Record 25 of Set 11 | lithgow
# Processing Record 26 of Set 11 | vinh long
# Processing Record 27 of Set 11 | siuri
# Processing Record 28 of Set 11 | vestmanna
# Processing Record 29 of Set 11 | donskoye
# Processing Record 30 of Set 11 | leh
# Processing Record 31 of Set 11 | payo
# Processing Record 32 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 11 | radyvyliv
# Processing Record 34 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 11 | boa vista
# Processing Record 36 of Set 11 | trat
# Processing Record 37 of Set 11 | kaoma
# Processing Record 38 of Set 11 | nybro
# Processing Record 39 of Set 11 | vanavara
# Processing Record 40 of Set 11 | krasnyy chikoy
# Processing Record 41 of Set 11 | deshna
# City not found. Skipping...
# Processing Record 42 of Set 11 | ashland
# Processing Record 43 of Set 11 | bulgan
# Processing Record 44 of Set 11 | secusigiu
# Processing Record 45 of Set 11 | berlevag
# Processing Record 46 of Set 11 | wellington
# Processing Record 47 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 11 | gat
# Processing Record 50 of Set 11 | tecoanapa
# Processing Record 1 of Set 12 | kaduqli
# Processing Record 2 of Set 12 | magdagachi
# Processing Record 3 of Set 12 | rawlins
# Processing Record 4 of Set 12 | astana
# Processing Record 5 of Set 12 | kharp
# Processing Record 6 of Set 12 | kahului
# Processing Record 7 of Set 12 | kaeo
# Processing Record 8 of Set 12 | sisophon
# Processing Record 9 of Set 12 | nekhayevskiy
# Processing Record 10 of Set 12 | nizhnevartovsk
# Processing Record 11 of Set 12 | buchanan
# Processing Record 12 of Set 12 | voh
# Processing Record 13 of Set 12 | fort saint james
# Processing Record 14 of Set 12 | manzhouli
# Processing Record 15 of Set 12 | atmakur
# Processing Record 16 of Set 12 | polunochnoye
# Processing Record 17 of Set 12 | kristiinankaupunki
# Processing Record 18 of Set 12 | severnoye
# Processing Record 19 of Set 12 | sorland
# Processing Record 20 of Set 12 | gull lake
# Processing Record 21 of Set 12 | ixtiyucan
# City not found. Skipping...
# Processing Record 22 of Set 12 | wad rawah
# Processing Record 23 of Set 12 | sinnamary
# Processing Record 24 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 12 | guerrero negro
# Processing Record 26 of Set 12 | jiexiu
# Processing Record 27 of Set 12 | harper
# Processing Record 28 of Set 12 | khandyga
# Processing Record 29 of Set 12 | gullhaug
# Processing Record 30 of Set 12 | isla mujeres
# Processing Record 31 of Set 12 | kindu
# Processing Record 32 of Set 12 | prince rupert
# Processing Record 33 of Set 12 | hearst
# Processing Record 34 of Set 12 | teeli
# Processing Record 35 of Set 12 | zhezkazgan
# Processing Record 36 of Set 12 | derzhavinsk
# Processing Record 37 of Set 12 | vostok
# Processing Record 38 of Set 12 | clyde river
# Processing Record 39 of Set 12 | morgan city
# Processing Record 40 of Set 12 | wielun
# Processing Record 41 of Set 12 | sibundoy
# Processing Record 42 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 43 of Set 12 | maroon town
# Processing Record 44 of Set 12 | snezhnogorsk
# Processing Record 45 of Set 12 | haimen
# Processing Record 46 of Set 12 | mazatlan
# Processing Record 47 of Set 12 | sucre
# Processing Record 48 of Set 12 | lockport
# Processing Record 49 of Set 12 | itarema
# Processing Record 50 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 1 of Set 13 | champerico
# Processing Record 2 of Set 13 | garm
# City not found. Skipping...
# Processing Record 3 of Set 13 | xinqing
# Processing Record 4 of Set 13 | natitingou
# Processing Record 5 of Set 13 | nampula
# Processing Record 6 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 13 | visnes
# Processing Record 8 of Set 13 | lashio
# Processing Record 9 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 13 | dagda
# Processing Record 11 of Set 13 | exu
# Processing Record 12 of Set 13 | nsanje
# Processing Record 13 of Set 13 | gravdal
# Processing Record 14 of Set 13 | hami
# Processing Record 15 of Set 13 | sayansk
# Processing Record 16 of Set 13 | sangueya
# Processing Record 17 of Set 13 | tutin
# Processing Record 18 of Set 13 | lasa
# Processing Record 19 of Set 13 | sisimiut
# Processing Record 20 of Set 13 | miramar
# Processing Record 21 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 22 of Set 13 | pontianak
# Processing Record 23 of Set 13 | nyandoma
# Processing Record 24 of Set 13 | sabang
# Processing Record 25 of Set 13 | mahendranagar
# Processing Record 26 of Set 13 | general roca
# Processing Record 27 of Set 13 | grindavik
# Processing Record 28 of Set 13 | tual
# Processing Record 29 of Set 13 | chifeng
# Processing Record 30 of Set 13 | mgandu
# Processing Record 31 of Set 13 | san luis
# Processing Record 32 of Set 13 | mayumba
# Processing Record 33 of Set 13 | cayenne
# Processing Record 34 of Set 13 | suez
# Processing Record 35 of Set 13 | karlshamn
# Processing Record 36 of Set 13 | weligama
# Processing Record 37 of Set 13 | jian
# Processing Record 38 of Set 13 | eureka
# Processing Record 39 of Set 13 | boulder city
# Processing Record 40 of Set 13 | beyneu
# Processing Record 41 of Set 13 | oistins
# Processing Record 42 of Set 13 | progreso
# Processing Record 43 of Set 13 | ust-ishim
# Processing Record 44 of Set 13 | butte
# Processing Record 45 of Set 13 | shitanjing
# Processing Record 46 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 13 | north branch
# Processing Record 48 of Set 13 | barra do bugres
# Processing Record 49 of Set 13 | constitucion
# Processing Record 50 of Set 13 | bathsheba
# Processing Record 1 of Set 14 | moerai
# Processing Record 2 of Set 14 | yabelo
# Processing Record 3 of Set 14 | christchurch
# Processing Record 4 of Set 14 | nakskov
# Processing Record 5 of Set 14 | vale
# Processing Record 6 of Set 14 | san policarpo
# Processing Record 7 of Set 14 | kirillov
# Processing Record 8 of Set 14 | luau
# Processing Record 9 of Set 14 | sibu
# Processing Record 10 of Set 14 | kenai
# Processing Record 11 of Set 14 | texarkana
# Processing Record 12 of Set 14 | baruun-urt
# Processing Record 13 of Set 14 | santa isabel do rio negro
# Processing Record 14 of Set 14 | krasnaya gorbatka
# Processing Record 15 of Set 14 | teknaf
# Processing Record 16 of Set 14 | taltal
# Processing Record 17 of Set 14 | kochetok
# Processing Record 18 of Set 14 | mehamn
# Processing Record 19 of Set 14 | araouane
# Processing Record 20 of Set 14 | jabinyanah
# Processing Record 21 of Set 14 | tautira
# Processing Record 22 of Set 14 | benavente
# Processing Record 23 of Set 14 | namwala
# Processing Record 24 of Set 14 | gangapur
# Processing Record 25 of Set 14 | ulladulla
# Processing Record 26 of Set 14 | dibaya
# City not found. Skipping...
# Processing Record 27 of Set 14 | malchevskaya
# Processing Record 28 of Set 14 | dunmore town
# Processing Record 29 of Set 14 | tahoua
# Processing Record 30 of Set 14 | simbahan
# Processing Record 31 of Set 14 | ust-nera
# Processing Record 32 of Set 14 | trinidad
# Processing Record 33 of Set 14 | moranbah
# Processing Record 34 of Set 14 | manohar thana
# Processing Record 35 of Set 14 | evensk
# Processing Record 36 of Set 14 | kon tum
# Processing Record 37 of Set 14 | ramgarh
# Processing Record 38 of Set 14 | la ronge
# Processing Record 39 of Set 14 | maloy
# Processing Record 40 of Set 14 | praia
# Processing Record 41 of Set 14 | copiapo
# Processing Record 42 of Set 14 | puri
# Processing Record 43 of Set 14 | lorengau
# Processing Record 44 of Set 14 | niamey
# Processing Record 45 of Set 14 | pedernales
# Processing Record 46 of Set 14 | gomel
# Processing Record 47 of Set 14 | rognan
# Processing Record 48 of Set 14 | salinopolis
# Processing Record 49 of Set 14 | viedma
# Processing Record 50 of Set 14 | fairlie
# Processing Record 1 of Set 15 | funtua
# Processing Record 2 of Set 15 | bonavista
# Processing Record 3 of Set 15 | burnie
# Processing Record 4 of Set 15 | bang saphan
# Processing Record 5 of Set 15 | iskar
# Processing Record 6 of Set 15 | pankovka
# Processing Record 7 of Set 15 | qandahar
# City not found. Skipping...
# Processing Record 8 of Set 15 | kargasok
# Processing Record 9 of Set 15 | nacala
# Processing Record 10 of Set 15 | port blair
# Processing Record 11 of Set 15 | burgeo
# Processing Record 12 of Set 15 | cochrane
# Processing Record 13 of Set 15 | ankazoabo
# Processing Record 14 of Set 15 | pancas
# Processing Record 15 of Set 15 | rio gallegos
# Processing Record 16 of Set 15 | pointe michel
# Processing Record 17 of Set 15 | nemuro
# Processing Record 18 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 15 | saryozek
# Processing Record 20 of Set 15 | eregli
# Processing Record 21 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 22 of Set 15 | tilichiki
# Processing Record 23 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 15 | prattville
# Processing Record 25 of Set 15 | san quintin
# Processing Record 26 of Set 15 | dwarka
# Processing Record 27 of Set 15 | balakhninskiy
# Processing Record 28 of Set 15 | westport
# Processing Record 29 of Set 15 | leshukonskoye
# Processing Record 30 of Set 15 | mae sai
# Processing Record 31 of Set 15 | sarkand
# Processing Record 32 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 33 of Set 15 | northam
# Processing Record 34 of Set 15 | hokitika
# Processing Record 35 of Set 15 | totskoye
# Processing Record 36 of Set 15 | kihei
# Processing Record 37 of Set 15 | crotone
# Processing Record 38 of Set 15 | roros
# Processing Record 39 of Set 15 | lewistown
# Processing Record 40 of Set 15 | danville
# Processing Record 41 of Set 15 | steinbach
# Processing Record 42 of Set 15 | bosaso
# Processing Record 43 of Set 15 | peleduy
# Processing Record 44 of Set 15 | sale
# Processing Record 45 of Set 15 | khuzhir
# Processing Record 46 of Set 15 | mogochin
# City not found. Skipping...
# Processing Record 47 of Set 15 | parfenyevo
# Processing Record 48 of Set 15 | anju
# Processing Record 49 of Set 15 | la victoria
# Processing Record 50 of Set 15 | seoul
# Processing Record 1 of Set 16 | impfondo
# Processing Record 2 of Set 16 | meadow lake
# Processing Record 3 of Set 16 | panaba
# Processing Record 4 of Set 16 | micheweni
# Processing Record 5 of Set 16 | lockhart
# Processing Record 6 of Set 16 | batticaloa
# Processing Record 7 of Set 16 | hualmay
# Processing Record 8 of Set 16 | rio grande
# Processing Record 9 of Set 16 | langsa
# Processing Record 10 of Set 16 | ascension
# Processing Record 11 of Set 16 | iskateley
# Processing Record 12 of Set 16 | ipora
# Processing Record 13 of Set 16 | anloga
# Processing Record 14 of Set 16 | villeta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Carmen  18.6333  -91.8333     87.84        62           0
# 1        Qaanaaq  77.4840  -69.3632     23.52        75          37
# 2          Lagoa  39.0500  -27.9833     56.34        66           7
# 3          Mecca  21.4267   39.8261     86.67        35           0
# 4      Carnarvon -24.8667  113.6333     69.46        59           0
# 5           Wuan  31.6836  112.0044     58.69        61           2
# 6         Palmer  42.1584  -72.3287     78.35        59          75
# 7     Nanortalik  60.1432  -45.2371     38.26        75          98
# 8         Soroti   1.7146   33.6111     65.66        85          24
# 9  Mar Del Plata -38.0023  -57.5575     52.95        85          75
#
#    Wind Speed Country                 Date
# 0       13.80      MX  2022-05-16 21:22:56
# 1        3.60      GL  2022-05-16 21:22:56
# 2       30.51      PT  2022-05-16 21:22:57
# 3        2.17      SA  2022-05-16 21:20:15
# 4        7.14      AU  2022-05-16 21:22:58
# 5        2.10      CN  2022-05-16 21:22:59
# 6       21.85      US  2022-05-16 21:22:59
# 7        7.05      GL  2022-05-16 21:22:59
# 8        5.91      UG  2022-05-16 21:23:00
# 9       12.66      AR  2022-05-16 21:23:00

# %%
# Create CSV file of DF
csv_weather_file = "Weatherpy_Database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")

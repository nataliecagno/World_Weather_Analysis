# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 757

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_wdescription = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_wdescription,
                          "Date": city_date})
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | moranbah
# Processing Record 3 of Set 1 | bac lieu
# Processing Record 4 of Set 1 | bonavista
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | morehead
# Processing Record 10 of Set 1 | kaseda
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | clyde river
# Processing Record 17 of Set 1 | skibbereen
# Processing Record 18 of Set 1 | meadow lake
# Processing Record 19 of Set 1 | lasa
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 22 of Set 1 | zhenhai
# Processing Record 23 of Set 1 | carutapera
# Processing Record 24 of Set 1 | san roque
# Processing Record 25 of Set 1 | naryan-mar
# Processing Record 26 of Set 1 | tual
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | iquique
# Processing Record 29 of Set 1 | waynesville
# Processing Record 30 of Set 1 | burley
# Processing Record 31 of Set 1 | te anau
# Processing Record 32 of Set 1 | half moon bay
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | watsa
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | mogilno
# Processing Record 42 of Set 1 | dembi dolo
# Processing Record 43 of Set 1 | kieta
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | sawtell
# Processing Record 47 of Set 1 | cidreira
# Processing Record 48 of Set 1 | klaksvik
# Processing Record 49 of Set 1 | mayo
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | fairbanks
# Processing Record 3 of Set 2 | bud
# Processing Record 4 of Set 2 | shimoda
# Processing Record 5 of Set 2 | nhulunbuy
# Processing Record 6 of Set 2 | altagracia de orituco
# Processing Record 7 of Set 2 | beloha
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | saint-paul
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | fortuna
# Processing Record 12 of Set 2 | kavieng
# Processing Record 13 of Set 2 | yar-sale
# Processing Record 14 of Set 2 | chuy
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | norman wells
# Processing Record 18 of Set 2 | ouidah
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | novyy svit
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 2 | lavrentiya
# Processing Record 25 of Set 2 | taltal
# Processing Record 26 of Set 2 | san rafael
# Processing Record 27 of Set 2 | galveston
# Processing Record 28 of Set 2 | pevek
# Processing Record 29 of Set 2 | lethem
# Processing Record 30 of Set 2 | gamba
# Processing Record 31 of Set 2 | avera
# Processing Record 32 of Set 2 | ndola
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | bambous virieux
# Processing Record 36 of Set 2 | shache
# Processing Record 37 of Set 2 | yefremov
# Processing Record 38 of Set 2 | maningrida
# Processing Record 39 of Set 2 | ko samui
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | kloulklubed
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | keetmanshoop
# Processing Record 44 of Set 2 | kununurra
# Processing Record 45 of Set 2 | podosinovets
# Processing Record 46 of Set 2 | pangnirtung
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | bathsheba
# Processing Record 49 of Set 2 | raudeberg
# Processing Record 50 of Set 2 | dikson
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | vierzon
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | mareeba
# Processing Record 7 of Set 3 | sajanan
# Processing Record 8 of Set 3 | andilamena
# Processing Record 9 of Set 3 | dillon
# Processing Record 10 of Set 3 | milledgeville
# Processing Record 11 of Set 3 | deer lake
# Processing Record 12 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 3 | mataura
# Processing Record 14 of Set 3 | cabedelo
# Processing Record 15 of Set 3 | talnakh
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | zhangye
# Processing Record 18 of Set 3 | airai
# Processing Record 19 of Set 3 | bluff
# Processing Record 20 of Set 3 | cheney
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | ancud
# Processing Record 23 of Set 3 | sambava
# Processing Record 24 of Set 3 | bakchar
# Processing Record 25 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 3 | chicama
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | yakeshi
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | inverell
# Processing Record 33 of Set 3 | moussoro
# Processing Record 34 of Set 3 | cervo
# Processing Record 35 of Set 3 | presidente epitacio
# Processing Record 36 of Set 3 | aykhal
# Processing Record 37 of Set 3 | sioux lookout
# Processing Record 38 of Set 3 | belmonte
# Processing Record 39 of Set 3 | ribeira grande
# Processing Record 40 of Set 3 | atbasar
# Processing Record 41 of Set 3 | santa maria
# Processing Record 42 of Set 3 | madimba
# Processing Record 43 of Set 3 | sicamous
# Processing Record 44 of Set 3 | svarstad
# Processing Record 45 of Set 3 | chokurdakh
# Processing Record 46 of Set 3 | camana
# Processing Record 47 of Set 3 | chintamani
# Processing Record 48 of Set 3 | kibre mengist
# Processing Record 49 of Set 3 | paamiut
# Processing Record 50 of Set 3 | mehamn
# Processing Record 1 of Set 4 | kharp
# Processing Record 2 of Set 4 | saint-pierre
# Processing Record 3 of Set 4 | arman
# Processing Record 4 of Set 4 | bethel
# Processing Record 5 of Set 4 | ye
# City not found. Skipping...
# Processing Record 6 of Set 4 | ponta do sol
# Processing Record 7 of Set 4 | qaanaaq
# Processing Record 8 of Set 4 | troitsk
# Processing Record 9 of Set 4 | zholymbet
# Processing Record 10 of Set 4 | iqaluit
# Processing Record 11 of Set 4 | montorio al vomano
# Processing Record 12 of Set 4 | chumikan
# Processing Record 13 of Set 4 | kahului
# Processing Record 14 of Set 4 | salalah
# Processing Record 15 of Set 4 | astoria
# Processing Record 16 of Set 4 | provideniya
# Processing Record 17 of Set 4 | webb city
# Processing Record 18 of Set 4 | yaan
# Processing Record 19 of Set 4 | rawson
# Processing Record 20 of Set 4 | faanui
# Processing Record 21 of Set 4 | maku
# Processing Record 22 of Set 4 | yellowknife
# Processing Record 23 of Set 4 | springdale
# Processing Record 24 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 4 | jalu
# Processing Record 26 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 27 of Set 4 | leh
# Processing Record 28 of Set 4 | port lincoln
# Processing Record 29 of Set 4 | loandjili
# Processing Record 30 of Set 4 | tasiilaq
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | saint-joseph
# Processing Record 33 of Set 4 | olafsvik
# Processing Record 34 of Set 4 | lorengau
# Processing Record 35 of Set 4 | haverhill
# Processing Record 36 of Set 4 | valdivia
# Processing Record 37 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 4 | nishihara
# Processing Record 39 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 4 | talara
# Processing Record 41 of Set 4 | livingston
# Processing Record 42 of Set 4 | dingle
# Processing Record 43 of Set 4 | saryg-sep
# Processing Record 44 of Set 4 | pacific grove
# Processing Record 45 of Set 4 | carnarvon
# Processing Record 46 of Set 4 | zyryanka
# Processing Record 47 of Set 4 | cedar city
# Processing Record 48 of Set 4 | sao joao da barra
# Processing Record 49 of Set 4 | severo-kurilsk
# Processing Record 50 of Set 4 | stykkisholmur
# Processing Record 1 of Set 5 | leua
# Processing Record 2 of Set 5 | cherskiy
# Processing Record 3 of Set 5 | beringovskiy
# Processing Record 4 of Set 5 | bushehr
# Processing Record 5 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 5 | maniitsoq
# Processing Record 7 of Set 5 | trujillo
# Processing Record 8 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 5 | san javier
# Processing Record 10 of Set 5 | nouadhibou
# Processing Record 11 of Set 5 | port-gentil
# Processing Record 12 of Set 5 | coacoyul
# Processing Record 13 of Set 5 | yulara
# Processing Record 14 of Set 5 | cheyenne
# Processing Record 15 of Set 5 | maragogi
# Processing Record 16 of Set 5 | hasaki
# Processing Record 17 of Set 5 | albanel
# Processing Record 18 of Set 5 | upernavik
# Processing Record 19 of Set 5 | shreveport
# Processing Record 20 of Set 5 | la asuncion
# Processing Record 21 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 22 of Set 5 | nelson bay
# Processing Record 23 of Set 5 | oksfjord
# Processing Record 24 of Set 5 | sur
# Processing Record 25 of Set 5 | salina cruz
# Processing Record 26 of Set 5 | guerrero negro
# Processing Record 27 of Set 5 | vanavara
# Processing Record 28 of Set 5 | vestmannaeyjar
# Processing Record 29 of Set 5 | victoria
# Processing Record 30 of Set 5 | makakilo city
# Processing Record 31 of Set 5 | new norfolk
# Processing Record 32 of Set 5 | aketi
# Processing Record 33 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 34 of Set 5 | hofn
# Processing Record 35 of Set 5 | bardiyah
# Processing Record 36 of Set 5 | marsa matruh
# Processing Record 37 of Set 5 | deputatskiy
# Processing Record 38 of Set 5 | grand gaube
# Processing Record 39 of Set 5 | itapetinga
# Processing Record 40 of Set 5 | wanning
# Processing Record 41 of Set 5 | portland
# Processing Record 42 of Set 5 | aklavik
# Processing Record 43 of Set 5 | mount gambier
# Processing Record 44 of Set 5 | grindavik
# Processing Record 45 of Set 5 | mchinji
# Processing Record 46 of Set 5 | zonguldak
# Processing Record 47 of Set 5 | ternate
# Processing Record 48 of Set 5 | chara
# Processing Record 49 of Set 5 | rosarito
# Processing Record 50 of Set 5 | ler
# Processing Record 1 of Set 6 | murud
# Processing Record 2 of Set 6 | estelle
# Processing Record 3 of Set 6 | tiarei
# Processing Record 4 of Set 6 | longyearbyen
# Processing Record 5 of Set 6 | mangrol
# Processing Record 6 of Set 6 | santiago
# Processing Record 7 of Set 6 | mugur-aksy
# Processing Record 8 of Set 6 | cairns
# Processing Record 9 of Set 6 | russkiy aktash
# Processing Record 10 of Set 6 | quelimane
# Processing Record 11 of Set 6 | san antonio
# Processing Record 12 of Set 6 | constitucion
# Processing Record 13 of Set 6 | lamu
# Processing Record 14 of Set 6 | kirakira
# Processing Record 15 of Set 6 | taiping
# Processing Record 16 of Set 6 | mporokoso
# Processing Record 17 of Set 6 | alofi
# Processing Record 18 of Set 6 | los llanos de aridane
# Processing Record 19 of Set 6 | najran
# Processing Record 20 of Set 6 | warmbad
# Processing Record 21 of Set 6 | kruisfontein
# Processing Record 22 of Set 6 | pisco
# Processing Record 23 of Set 6 | zhanakorgan
# Processing Record 24 of Set 6 | tezu
# Processing Record 25 of Set 6 | tommot
# Processing Record 26 of Set 6 | taphan hin
# Processing Record 27 of Set 6 | mananara
# Processing Record 28 of Set 6 | tessalit
# Processing Record 29 of Set 6 | vestmanna
# Processing Record 30 of Set 6 | alyangula
# Processing Record 31 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 6 | leningradskiy
# Processing Record 33 of Set 6 | wanaka
# Processing Record 34 of Set 6 | touros
# Processing Record 35 of Set 6 | bemidji
# Processing Record 36 of Set 6 | bandarbeyla
# Processing Record 37 of Set 6 | margate
# Processing Record 38 of Set 6 | murgab
# Processing Record 39 of Set 6 | lalmohan
# Processing Record 40 of Set 6 | auki
# Processing Record 41 of Set 6 | kaabong
# Processing Record 42 of Set 6 | road town
# Processing Record 43 of Set 6 | khanu woralaksaburi
# Processing Record 44 of Set 6 | norton shores
# Processing Record 45 of Set 6 | flinders
# Processing Record 46 of Set 6 | hamilton
# Processing Record 47 of Set 6 | tamandare
# Processing Record 48 of Set 6 | monrovia
# Processing Record 49 of Set 6 | acapulco
# Processing Record 50 of Set 6 | panzhihua
# Processing Record 1 of Set 7 | port moresby
# Processing Record 2 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 3 of Set 7 | saldanha
# Processing Record 4 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 5 of Set 7 | kolimvari
# City not found. Skipping...
# Processing Record 6 of Set 7 | buraydah
# Processing Record 7 of Set 7 | la palma
# Processing Record 8 of Set 7 | san ramon
# Processing Record 9 of Set 7 | milazzo
# Processing Record 10 of Set 7 | north bend
# Processing Record 11 of Set 7 | mandalgovi
# Processing Record 12 of Set 7 | lompoc
# Processing Record 13 of Set 7 | sakakah
# Processing Record 14 of Set 7 | bengkulu
# Processing Record 15 of Set 7 | nador
# Processing Record 16 of Set 7 | presidencia roque saenz pena
# Processing Record 17 of Set 7 | tungawan
# Processing Record 18 of Set 7 | koumac
# Processing Record 19 of Set 7 | maceio
# Processing Record 20 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 7 | betare oya
# Processing Record 22 of Set 7 | novoukrainskiy
# Processing Record 23 of Set 7 | los corrales de buelna
# Processing Record 24 of Set 7 | ilulissat
# Processing Record 25 of Set 7 | falam
# Processing Record 26 of Set 7 | belton
# Processing Record 27 of Set 7 | lopukhiv
# Processing Record 28 of Set 7 | oranjemund
# Processing Record 29 of Set 7 | shaunavon
# Processing Record 30 of Set 7 | dunbar
# Processing Record 31 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 32 of Set 7 | kaitangata
# Processing Record 33 of Set 7 | kamaishi
# Processing Record 34 of Set 7 | ridgecrest
# Processing Record 35 of Set 7 | iralaya
# Processing Record 36 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 7 | ostrovnoy
# Processing Record 38 of Set 7 | praia da vitoria
# Processing Record 39 of Set 7 | nanning
# Processing Record 40 of Set 7 | santa marta
# Processing Record 41 of Set 7 | emilio carranza
# Processing Record 42 of Set 7 | sumbe
# Processing Record 43 of Set 7 | pala
# Processing Record 44 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 7 | mitsamiouli
# Processing Record 46 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 7 | yatou
# Processing Record 48 of Set 7 | zemio
# Processing Record 49 of Set 7 | licata
# Processing Record 50 of Set 7 | petropavlovka
# Processing Record 1 of Set 8 | mecca
# Processing Record 2 of Set 8 | joao pinheiro
# Processing Record 3 of Set 8 | ketchikan
# Processing Record 4 of Set 8 | sola
# Processing Record 5 of Set 8 | quatre cocos
# Processing Record 6 of Set 8 | saint george
# Processing Record 7 of Set 8 | teya
# Processing Record 8 of Set 8 | sinazongwe
# Processing Record 9 of Set 8 | santa ana
# Processing Record 10 of Set 8 | kenai
# Processing Record 11 of Set 8 | nanortalik
# Processing Record 12 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 13 of Set 8 | praya
# Processing Record 14 of Set 8 | batie
# Processing Record 15 of Set 8 | concepcion
# Processing Record 16 of Set 8 | karaton
# Processing Record 17 of Set 8 | bowen
# Processing Record 18 of Set 8 | presidente dutra
# Processing Record 19 of Set 8 | san andres
# Processing Record 20 of Set 8 | itapirapua
# Processing Record 21 of Set 8 | manggar
# Processing Record 22 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 8 | hokitika
# Processing Record 24 of Set 8 | lusambo
# Processing Record 25 of Set 8 | marsh harbour
# Processing Record 26 of Set 8 | estacion coahuila
# Processing Record 27 of Set 8 | puri
# Processing Record 28 of Set 8 | porto tolle
# Processing Record 29 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 8 | orgun
# City not found. Skipping...
# Processing Record 31 of Set 8 | yerbogachen
# Processing Record 32 of Set 8 | san buenaventura
# Processing Record 33 of Set 8 | batagay
# Processing Record 34 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 8 | tuatapere
# Processing Record 36 of Set 8 | omboue
# Processing Record 37 of Set 8 | chunhuhub
# Processing Record 38 of Set 8 | georgetown
# Processing Record 39 of Set 8 | ilinskiy
# Processing Record 40 of Set 8 | nuevo progreso
# Processing Record 41 of Set 8 | wasilla
# Processing Record 42 of Set 8 | walvis bay
# Processing Record 43 of Set 8 | muzhi
# Processing Record 44 of Set 8 | samarai
# Processing Record 45 of Set 8 | husavik
# Processing Record 46 of Set 8 | indiana
# Processing Record 47 of Set 8 | panjakent
# Processing Record 48 of Set 8 | jiangyou
# Processing Record 49 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 8 | rocha
# Processing Record 1 of Set 9 | nantucket
# Processing Record 2 of Set 9 | qaqortoq
# Processing Record 3 of Set 9 | karratha
# Processing Record 4 of Set 9 | coihueco
# Processing Record 5 of Set 9 | hovd
# Processing Record 6 of Set 9 | valley city
# Processing Record 7 of Set 9 | puerto quijarro
# Processing Record 8 of Set 9 | pushkino
# Processing Record 9 of Set 9 | vuktyl
# Processing Record 10 of Set 9 | cockburn town
# Processing Record 11 of Set 9 | moiyabana
# City not found. Skipping...
# Processing Record 12 of Set 9 | miguel calmon
# Processing Record 13 of Set 9 | katsuura
# Processing Record 14 of Set 9 | sinegorye
# Processing Record 15 of Set 9 | manokwari
# Processing Record 16 of Set 9 | sobolevo
# Processing Record 17 of Set 9 | riyadh
# Processing Record 18 of Set 9 | farafangana
# Processing Record 19 of Set 9 | metro
# Processing Record 20 of Set 9 | namatanai
# Processing Record 21 of Set 9 | niquelandia
# Processing Record 22 of Set 9 | rovaniemi
# Processing Record 23 of Set 9 | haapiti
# Processing Record 24 of Set 9 | rangapara
# Processing Record 25 of Set 9 | valparaiso
# Processing Record 26 of Set 9 | benjamin constant
# Processing Record 27 of Set 9 | jiaozuo
# Processing Record 28 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 9 | coihaique
# Processing Record 30 of Set 9 | ust-tsilma
# Processing Record 31 of Set 9 | san quintin
# Processing Record 32 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 9 | houston
# Processing Record 34 of Set 9 | springbok
# Processing Record 35 of Set 9 | rundu
# Processing Record 36 of Set 9 | camacha
# Processing Record 37 of Set 9 | vao
# Processing Record 38 of Set 9 | edd
# Processing Record 39 of Set 9 | berlevag
# Processing Record 40 of Set 9 | port blair
# Processing Record 41 of Set 9 | pyapon
# Processing Record 42 of Set 9 | estevan
# Processing Record 43 of Set 9 | broken hill
# Processing Record 44 of Set 9 | cabo san lucas
# Processing Record 45 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 9 | ust-koksa
# Processing Record 47 of Set 9 | redmond
# Processing Record 48 of Set 9 | bilibino
# Processing Record 49 of Set 9 | usinsk
# Processing Record 50 of Set 9 | santa isabel do rio negro
# Processing Record 1 of Set 10 | sainte-suzanne
# Processing Record 2 of Set 10 | labuhan
# Processing Record 3 of Set 10 | lebu
# Processing Record 4 of Set 10 | bara
# Processing Record 5 of Set 10 | belomorsk
# Processing Record 6 of Set 10 | bilma
# Processing Record 7 of Set 10 | san marco in lamis
# Processing Record 8 of Set 10 | talcahuano
# Processing Record 9 of Set 10 | zambezi
# Processing Record 10 of Set 10 | gat
# Processing Record 11 of Set 10 | umm lajj
# Processing Record 12 of Set 10 | kavaratti
# Processing Record 13 of Set 10 | corralillo
# Processing Record 14 of Set 10 | vanimo
# Processing Record 15 of Set 10 | xinyu
# Processing Record 16 of Set 10 | guymon
# Processing Record 17 of Set 10 | taywarah
# Processing Record 18 of Set 10 | sinnamary
# Processing Record 19 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 20 of Set 10 | korla
# Processing Record 21 of Set 10 | crossville
# Processing Record 22 of Set 10 | wana
# Processing Record 23 of Set 10 | vila velha
# Processing Record 24 of Set 10 | jasper
# Processing Record 25 of Set 10 | rafaela
# Processing Record 26 of Set 10 | vologda
# Processing Record 27 of Set 10 | lagoa
# Processing Record 28 of Set 10 | viedma
# Processing Record 29 of Set 10 | japura
# Processing Record 30 of Set 10 | narsaq
# Processing Record 31 of Set 10 | rohnert park
# Processing Record 32 of Set 10 | steinbach
# Processing Record 33 of Set 10 | paso de carrasco
# Processing Record 34 of Set 10 | yershov
# Processing Record 35 of Set 10 | lata
# Processing Record 36 of Set 10 | saint-georges
# Processing Record 37 of Set 10 | pierre
# Processing Record 38 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 39 of Set 10 | dunedin
# Processing Record 40 of Set 10 | rio gallegos
# Processing Record 41 of Set 10 | pokanayevka
# City not found. Skipping...
# Processing Record 42 of Set 10 | dundalk
# Processing Record 43 of Set 10 | turbat
# Processing Record 44 of Set 10 | maroantsetra
# Processing Record 45 of Set 10 | sterling
# Processing Record 46 of Set 10 | villamontes
# Processing Record 47 of Set 10 | geraldton
# Processing Record 48 of Set 10 | mount isa
# Processing Record 49 of Set 10 | marawi
# Processing Record 50 of Set 10 | san bartolome de tirajana
# Processing Record 1 of Set 11 | dovbysh
# Processing Record 2 of Set 11 | paramonga
# Processing Record 3 of Set 11 | high level
# Processing Record 4 of Set 11 | makaryev
# Processing Record 5 of Set 11 | high rock
# Processing Record 6 of Set 11 | saint-denis
# Processing Record 7 of Set 11 | redlands
# Processing Record 8 of Set 11 | alice springs
# Processing Record 9 of Set 11 | saint anthony
# Processing Record 10 of Set 11 | dubbo
# Processing Record 11 of Set 11 | vostok
# Processing Record 12 of Set 11 | rolla
# Processing Record 13 of Set 11 | grand-santi
# Processing Record 14 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 11 | kiunga
# Processing Record 16 of Set 11 | atasu
# Processing Record 17 of Set 11 | antofagasta
# Processing Record 18 of Set 11 | sao filipe
# Processing Record 19 of Set 11 | cascais
# Processing Record 20 of Set 11 | san cristobal
# Processing Record 21 of Set 11 | reims
# Processing Record 22 of Set 11 | urambo
# Processing Record 23 of Set 11 | yangjiang
# Processing Record 24 of Set 11 | lanxi
# Processing Record 25 of Set 11 | kawalu
# Processing Record 26 of Set 11 | poum
# Processing Record 27 of Set 11 | barra
# Processing Record 28 of Set 11 | sisimiut
# Processing Record 29 of Set 11 | burnie
# Processing Record 30 of Set 11 | georgiyevskoye
# Processing Record 31 of Set 11 | abha
# Processing Record 32 of Set 11 | santa lucia
# Processing Record 33 of Set 11 | sheridan
# Processing Record 34 of Set 11 | muli
# Processing Record 35 of Set 11 | ipixuna
# Processing Record 36 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 11 | vila franca do campo
# Processing Record 38 of Set 11 | simao
# Processing Record 39 of Set 11 | marzuq
# Processing Record 40 of Set 11 | tocopilla
# Processing Record 41 of Set 11 | barabash
# Processing Record 42 of Set 11 | batagay-alyta
# Processing Record 43 of Set 11 | shimanovsk
# Processing Record 44 of Set 11 | ranong
# Processing Record 45 of Set 11 | otradnaya
# Processing Record 46 of Set 11 | westport
# Processing Record 47 of Set 11 | mana
# Processing Record 48 of Set 11 | broome
# Processing Record 49 of Set 11 | ixtapa
# Processing Record 50 of Set 11 | tombouctou
# Processing Record 1 of Set 12 | panguna
# Processing Record 2 of Set 12 | bull savanna
# Processing Record 3 of Set 12 | capari
# Processing Record 4 of Set 12 | palu
# Processing Record 5 of Set 12 | izazi
# Processing Record 6 of Set 12 | promissao
# Processing Record 7 of Set 12 | clevelandia
# Processing Record 8 of Set 12 | ambon
# Processing Record 9 of Set 12 | kolo
# Processing Record 10 of Set 12 | sao sebastiao
# Processing Record 11 of Set 12 | palmer
# Processing Record 12 of Set 12 | vardo
# Processing Record 13 of Set 12 | faya
# Processing Record 14 of Set 12 | komsomolskiy
# Processing Record 15 of Set 12 | caravelas
# Processing Record 16 of Set 12 | the valley
# Processing Record 17 of Set 12 | ust-nera
# Processing Record 18 of Set 12 | aswan
# Processing Record 19 of Set 12 | milkovo
# Processing Record 20 of Set 12 | tomatlan
# Processing Record 21 of Set 12 | kousseri
# Processing Record 22 of Set 12 | urumqi
# Processing Record 23 of Set 12 | nichinan
# Processing Record 24 of Set 12 | port hawkesbury
# Processing Record 25 of Set 12 | tautira
# Processing Record 26 of Set 12 | balkhash
# Processing Record 27 of Set 12 | bardsir
# Processing Record 28 of Set 12 | oktyabrskiy
# Processing Record 29 of Set 12 | charters towers
# Processing Record 30 of Set 12 | muros
# Processing Record 31 of Set 12 | coahuayana
# Processing Record 32 of Set 12 | verkhnyaya inta
# Processing Record 33 of Set 12 | santa rosa
# Processing Record 34 of Set 12 | sao felix do xingu
# Processing Record 35 of Set 12 | andros
# Processing Record 36 of Set 12 | cortez
# Processing Record 37 of Set 12 | souillac
# Processing Record 38 of Set 12 | middelburg
# Processing Record 39 of Set 12 | gizo
# Processing Record 40 of Set 12 | kachug
# Processing Record 41 of Set 12 | san patricio
# Processing Record 42 of Set 12 | havelock
# Processing Record 43 of Set 12 | ermioni
# Processing Record 44 of Set 12 | fort nelson
# Processing Record 45 of Set 12 | yeniseysk
# Processing Record 46 of Set 12 | solnechnyy
# Processing Record 47 of Set 12 | taunggyi
# Processing Record 48 of Set 12 | sao paulo de olivenca
# Processing Record 49 of Set 12 | puerto leguizamo
# Processing Record 50 of Set 12 | goderich
# Processing Record 1 of Set 13 | dagana
# Processing Record 2 of Set 13 | ukiah
# Processing Record 3 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 13 | kitob
# Processing Record 5 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 13 | ruidoso
# Processing Record 7 of Set 13 | phuket
# Processing Record 8 of Set 13 | port hardy
# Processing Record 9 of Set 13 | uthal
# Processing Record 10 of Set 13 | lisakovsk
# Processing Record 11 of Set 13 | les cayes
# Processing Record 12 of Set 13 | sorong
# Processing Record 13 of Set 13 | nome
# Processing Record 14 of Set 13 | vagamo
# Processing Record 15 of Set 13 | karasjok
# Processing Record 16 of Set 13 | nusaybin
# Processing Record 17 of Set 13 | mazabuka
# Processing Record 18 of Set 13 | dhidhdhoo
# Processing Record 19 of Set 13 | harlingen
# Processing Record 20 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 13 | jinchang
# Processing Record 22 of Set 13 | podyuga
# Processing Record 23 of Set 13 | naranjito
# Processing Record 24 of Set 13 | pyatnitskoye
# Processing Record 25 of Set 13 | antagan
# City not found. Skipping...
# Processing Record 26 of Set 13 | thomaston
# Processing Record 27 of Set 13 | ercis
# Processing Record 28 of Set 13 | aitape
# Processing Record 29 of Set 13 | biltine
# Processing Record 30 of Set 13 | kleck
# City not found. Skipping...
# Processing Record 31 of Set 13 | olinda
# Processing Record 32 of Set 13 | port macquarie
# Processing Record 33 of Set 13 | khandbari
# Processing Record 34 of Set 13 | porirua
# Processing Record 35 of Set 13 | lemesos
# City not found. Skipping...
# Processing Record 36 of Set 13 | matagami
# Processing Record 37 of Set 13 | batemans bay
# Processing Record 38 of Set 13 | seminole
# Processing Record 39 of Set 13 | honningsvag
# Processing Record 40 of Set 13 | lebowakgomo
# Processing Record 41 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 42 of Set 13 | kinkala
# Processing Record 43 of Set 13 | sept-iles
# Processing Record 44 of Set 13 | progreso
# Processing Record 45 of Set 13 | velikiy ustyug
# Processing Record 46 of Set 13 | ardakan
# Processing Record 47 of Set 13 | uige
# Processing Record 48 of Set 13 | rongcheng
# Processing Record 49 of Set 13 | joetsu
# Processing Record 50 of Set 13 | basqal
# Processing Record 1 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 14 | birao
# Processing Record 3 of Set 14 | kijang
# Processing Record 4 of Set 14 | general pico
# Processing Record 5 of Set 14 | nuuk
# Processing Record 6 of Set 14 | basar
# Processing Record 7 of Set 14 | woodward
# Processing Record 8 of Set 14 | bogatyr
# Processing Record 9 of Set 14 | vilhena
# Processing Record 10 of Set 14 | cap-aux-meules
# Processing Record 11 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 12 of Set 14 | caraballeda
# Processing Record 13 of Set 14 | pitimbu
# Processing Record 14 of Set 14 | mwinilunga
# Processing Record 15 of Set 14 | shahr-e babak
# Processing Record 16 of Set 14 | whitianga
# Processing Record 17 of Set 14 | madera
# Processing Record 18 of Set 14 | anadyr
# Processing Record 19 of Set 14 | qasigiannguit
# Processing Record 20 of Set 14 | barabai
# Processing Record 21 of Set 14 | apango
# Processing Record 22 of Set 14 | kidal
# Processing Record 23 of Set 14 | general roca
# Processing Record 24 of Set 14 | kristianstad
# Processing Record 25 of Set 14 | kalanguy
# Processing Record 26 of Set 14 | henties bay
# Processing Record 27 of Set 14 | isangel
# Processing Record 28 of Set 14 | esperance
# Processing Record 29 of Set 14 | mao
# Processing Record 30 of Set 14 | trofors
# Processing Record 31 of Set 14 | llangefni
# Processing Record 32 of Set 14 | altamira
# Processing Record 33 of Set 14 | lishui
# Processing Record 34 of Set 14 | bubaque
# Processing Record 35 of Set 14 | kimbe
# Processing Record 36 of Set 14 | ormara
# Processing Record 37 of Set 14 | loreto
# Processing Record 38 of Set 14 | namibe
# Processing Record 39 of Set 14 | hervey bay
# Processing Record 40 of Set 14 | launceston
# Processing Record 41 of Set 14 | calvinia
# Processing Record 42 of Set 14 | moerai
# Processing Record 43 of Set 14 | rancho palos verdes
# Processing Record 44 of Set 14 | ponta delgada
# Processing Record 45 of Set 14 | gejiu
# Processing Record 46 of Set 14 | iracoubo
# Processing Record 47 of Set 14 | moa
# Processing Record 48 of Set 14 | salym
# Processing Record 49 of Set 14 | boende
# Processing Record 50 of Set 14 | chapais
# Processing Record 1 of Set 15 | linkou
# Processing Record 2 of Set 15 | waingapu
# Processing Record 3 of Set 15 | tacoronte
# Processing Record 4 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 15 | smirnykh
# Processing Record 6 of Set 15 | zhangjiakou
# Processing Record 7 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 15 | dibombari
# Processing Record 9 of Set 15 | shubarshi
# Processing Record 10 of Set 15 | mumbwa
# Processing Record 11 of Set 15 | greenfield
# Processing Record 12 of Set 15 | simplicio mendes
# Processing Record 13 of Set 15 | boden
# Processing Record 14 of Set 15 | dobryanka
# Processing Record 15 of Set 15 | anloga
# Processing Record 16 of Set 15 | hualmay
# Processing Record 17 of Set 15 | flin flon
# Processing Record 18 of Set 15 | byron bay
# Processing Record 19 of Set 15 | necochea
# Processing Record 20 of Set 15 | haines junction
# Processing Record 21 of Set 15 | caxias
# Processing Record 22 of Set 15 | huarmey
# Processing Record 23 of Set 15 | srednekolymsk
# Processing Record 24 of Set 15 | axochiapan
# Processing Record 25 of Set 15 | troitsko-pechorsk
# Processing Record 26 of Set 15 | bethpage
# Processing Record 27 of Set 15 | urdoma
# Processing Record 28 of Set 15 | teknaf
# Processing Record 29 of Set 15 | moose factory
# Processing Record 30 of Set 15 | deep river
# Processing Record 31 of Set 15 | eyl
# Processing Record 32 of Set 15 | nelson
# Processing Record 33 of Set 15 | cocobeach
# Processing Record 34 of Set 15 | akureyri
# Processing Record 35 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 36 of Set 15 | hassan
# Processing Record 37 of Set 15 | xai-xai
# Processing Record 38 of Set 15 | evinayong
# Processing Record 39 of Set 15 | tura
# Processing Record 40 of Set 15 | yelizovo
# Processing Record 41 of Set 15 | nyrob
# Processing Record 42 of Set 15 | comodoro rivadavia
# Processing Record 43 of Set 15 | chimbote
# Processing Record 44 of Set 15 | seydisehir
# Processing Record 45 of Set 15 | lazaro cardenas
# Processing Record 46 of Set 15 | zangakatun
# Processing Record 47 of Set 15 | biak
# Processing Record 48 of Set 15 | rodrigues alves
# Processing Record 49 of Set 15 | hearst
# Processing Record 50 of Set 15 | ambilobe
# Processing Record 1 of Set 16 | rantepao
# Processing Record 2 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 16 | axim
# Processing Record 4 of Set 16 | bassila
# Processing Record 5 of Set 16 | verkhnyaya toyma
# Processing Record 6 of Set 16 | arawa
# Processing Record 7 of Set 16 | mpika
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Carmen  18.6333  -91.8333     87.84        62           0
# 1        Qaanaaq  77.4840  -69.3632     23.52        75          37
# 2          Lagoa  39.0500  -27.9833     56.34        66           7
# 3          Mecca  21.4267   39.8261     86.67        35           0
# 4      Carnarvon -24.8667  113.6333     69.46        59           0
# 5           Wuan  31.6836  112.0044     58.69        61           2
# 6         Palmer  42.1584  -72.3287     78.35        59          75
# 7     Nanortalik  60.1432  -45.2371     38.26        75          98
# 8         Soroti   1.7146   33.6111     65.66        85          24
# 9  Mar Del Plata -38.0023  -57.5575     52.95        85          75
#
#    Wind Speed Country                 Date Current Description
# 0       13.80      MX  2022-05-16 21:22:56                 NaN
# 1        3.60      GL  2022-05-16 21:22:56                 NaN
# 2       30.51      PT  2022-05-16 21:22:57                 NaN
# 3        2.17      SA  2022-05-16 21:20:15                 NaN
# 4        7.14      AU  2022-05-16 21:22:58                 NaN
# 5        2.10      CN  2022-05-16 21:22:59                 NaN
# 6       21.85      US  2022-05-16 21:22:59                 NaN
# 7        7.05      GL  2022-05-16 21:22:59                 NaN
# 8        5.91      UG  2022-05-16 21:23:00                 NaN
# 9       12.66      AR  2022-05-16 21:23:00                 NaN

# %%
new_city_data_df = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df.reindex(columns=new_city_data_df)

# %%
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Carmen      MX  18.6333  -91.8333     87.84        62           0
# 1        Qaanaaq      GL  77.4840  -69.3632     23.52        75          37
# 2          Lagoa      PT  39.0500  -27.9833     56.34        66           7
# 3          Mecca      SA  21.4267   39.8261     86.67        35           0
# 4      Carnarvon      AU -24.8667  113.6333     69.46        59           0
# 5           Wuan      CN  31.6836  112.0044     58.69        61           2
# 6         Palmer      US  42.1584  -72.3287     78.35        59          75
# 7     Nanortalik      GL  60.1432  -45.2371     38.26        75          98
# 8         Soroti      UG   1.7146   33.6111     65.66        85          24
# 9  Mar Del Plata      AR -38.0023  -57.5575     52.95        85          75
#
#    Wind Speed Current Description
# 0       13.80                 NaN
# 1        3.60                 NaN
# 2       30.51                 NaN
# 3        2.17                 NaN
# 4        7.14                 NaN
# 5        2.10                 NaN
# 6       21.85                 NaN
# 7        7.05                 NaN
# 8        5.91                 NaN
# 9       12.66                 NaN

# %%
# Create CSV file of DF
csv_weather_file = "Weatherpy_Database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
